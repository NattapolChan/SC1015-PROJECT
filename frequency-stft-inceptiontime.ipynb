# %%
from utils.train_stft import fit_cnn_stft
import pandas as pd
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
from ray.tune.search.optuna import OptunaSearch
from ray.air import RunConfig
import warnings

warnings.filterwarnings('ignore')

CONFIG = {
    "dropout": tune.choice([0.1,0.2]),
    "f_start": tune.choice([0, 100, 200, 300, 400, 500, 600, 700]),
    "batch_size": tune.choice([512, 256]),
    "learning_rate": tune.loguniform(1e-4, 1e-2),
    "input_channels": tune.choice([32,64,128]),
}

reporter = CLIReporter(
        parameter_columns=["input_channels", "dropout", "learning_rate", "batch_size", "f_start"],
        metric_columns=["loss", "accuracy", "training_iteration"])

algo = OptunaSearch()

tuner = tune.Tuner(
        tune.with_resources(
                tune.with_parameters(fit_cnn_stft),
                resources={"cpu": 16, "gpu": 2}
        ),
        tune_config=tune.TuneConfig(
                metric='g_mean',
                mode="max",
                search_alg=algo,
                num_samples=10,
        ),
        run_config=RunConfig(
                stop={"training_iteration": 10},
                verbose=2,
        ),
        param_space=CONFIG,
)

results = tuner.fit()

best_result = results.get_best_result("g_mean", "max")
print("Best config is:", results.get_best_result().config)
# Out:
# [I 2023-04-22 23:21:35,647] A new study created in memory with name: optuna
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2023-04-22 23:21:37</td></tr>
# <tr><td>Running for: </td><td>00:00:02.13        </td></tr>
# <tr><td>Memory:      </td><td>27.4/251.6 GiB     </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Resources requested: 16.0/32 CPUs, 2.0/2 GPUs, 0.0/202.35 GiB heap, 0.0/9.31 GiB objects (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name           </th><th>status  </th><th>loc                </th><th style="text-align: right;">  batch_size</th><th style="text-align: right;">  dropout</th><th style="text-align: right;">  f_start</th><th style="text-align: right;">  input_channels</th><th style="text-align: right;">  learning_rate</th></tr>
# </thead>
# <tbody>
# <tr><td>fit_cnn_stft_973aae98</td><td>RUNNING </td><td>192.168.96.6:325499</td><td style="text-align: right;">         512</td><td style="text-align: right;">      0.1</td><td style="text-align: right;">      100</td><td style="text-align: right;">              64</td><td style="text-align: right;">     0.00682465</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name           </th><th style="text-align: right;">  accuracy</th><th style="text-align: right;">  extrastole_tpr</th><th style="text-align: right;">  extrastole_val_tpr</th><th style="text-align: right;">  g_mean</th><th style="text-align: right;">      loss</th><th style="text-align: right;">  murmur_tpr</th><th style="text-align: right;">  murmur_val_tpr</th><th>should_checkpoint  </th><th style="text-align: right;">  val_accuracy</th><th style="text-align: right;">  val_loss</th></tr>
# </thead>
# <tbody>
# <tr><td>fit_cnn_stft_973aae98</td><td style="text-align: right;">  0.630532</td><td style="text-align: right;">        0.674086</td><td style="text-align: right;">            0.563636</td><td style="text-align: right;">0.322438</td><td style="text-align: right;">0.00203658</td><td style="text-align: right;">    0.478333</td><td style="text-align: right;">        0.916667</td><td>True               </td><td style="text-align: right;">      0.413598</td><td style="text-align: right;">0.00333855</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .trialProgress {
#   display: flex;
#   flex-direction: column;
#   color: var(--jp-ui-font-color1);
# }
# .trialProgress h3 {
#   font-weight: bold;
# }
# .trialProgress td {
#   white-space: nowrap;
# }
# </style>
# (fit_cnn_stft pid=325499) Frequency from 100 to 200
# (fit_cnn_stft pid=325499)               precision    recall  f1-score   support
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)       normal       0.84      0.23      0.36       202
# (fit_cnn_stft pid=325499)       murmur       0.53      0.44      0.48        96
# (fit_cnn_stft pid=325499)   extrastole       0.25      1.00      0.40        55
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)     accuracy                           0.41       353
# (fit_cnn_stft pid=325499)    macro avg       0.54      0.56      0.42       353
# (fit_cnn_stft pid=325499) weighted avg       0.66      0.41      0.40       353
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499) Frequency from 100 to 200
# (fit_cnn_stft pid=325499)               precision    recall  f1-score   support
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)       normal       0.75      0.40      0.52       170
# (fit_cnn_stft pid=325499)       murmur       0.47      0.44      0.46        97
# (fit_cnn_stft pid=325499)   extrastole       0.39      0.79      0.53        85
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)     accuracy                           0.51       352
# (fit_cnn_stft pid=325499)    macro avg       0.54      0.54      0.50       352
# (fit_cnn_stft pid=325499) weighted avg       0.59      0.51      0.50       352
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499) Frequency from 100 to 200
# (fit_cnn_stft pid=325499)               precision    recall  f1-score   support
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)       normal       0.47      0.86      0.61       164
# (fit_cnn_stft pid=325499)       murmur       0.93      0.38      0.54       139
# (fit_cnn_stft pid=325499)   extrastole       0.62      0.33      0.43       107
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)     accuracy                           0.56       410
# (fit_cnn_stft pid=325499)    macro avg       0.68      0.52      0.53       410
# (fit_cnn_stft pid=325499) weighted avg       0.67      0.56      0.54       410
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499) Frequency from 100 to 200
# (fit_cnn_stft pid=325499)               precision    recall  f1-score   support
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)       normal       0.60      0.44      0.51       218
# (fit_cnn_stft pid=325499)       murmur       0.54      0.55      0.55        71
# (fit_cnn_stft pid=325499)   extrastole       0.33      0.49      0.39       115
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)     accuracy                           0.47       404
# (fit_cnn_stft pid=325499)    macro avg       0.49      0.49      0.48       404
# (fit_cnn_stft pid=325499) weighted avg       0.51      0.47      0.48       404
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499) Frequency from 700 to 800
# (fit_cnn_stft pid=325499)               precision    recall  f1-score   support
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)       normal       0.84      0.17      0.29       179
# (fit_cnn_stft pid=325499)       murmur       0.00      0.00      0.00       126
# (fit_cnn_stft pid=325499)   extrastole       0.12      1.00      0.22        37
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499)     accuracy                           0.20       342
# (fit_cnn_stft pid=325499)    macro avg       0.32      0.39      0.17       342
# (fit_cnn_stft pid=325499) weighted avg       0.45      0.20      0.17       342
# (fit_cnn_stft pid=325499)
# (fit_cnn_stft pid=325499) /root/miniconda3/envs/UGaze/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# (fit_cnn_stft pid=325499)   _warn_prf(average, modifier, msg_start, len(result))
# (fit_cnn_stft pid=325499) /root/miniconda3/envs/UGaze/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# (fit_cnn_stft pid=325499)   _warn_prf(average, modifier, msg_start, len(result))
# (fit_cnn_stft pid=325499) /root/miniconda3/envs/UGaze/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1327: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# (fit_cnn_stft pid=325499)   _warn_prf(average, modifier, msg_start, len(result))
# 2023-04-22 23:26:27,076	INFO tune.py:798 -- Total run time: 291.43 seconds (291.40 seconds for the tuning loop).
# Best config is: {'dropout': 0.1, 'f_start': 100, 'batch_size': 512, 'learning_rate': 0.00682465163171436, 'input_channels': 64}

# %%
results.get_dataframe()
# Out:
#        loss  accuracy    g_mean  murmur_tpr  extrastole_tpr  val_loss
# 0  0.003827  0.706567  0.690549    0.800743        0.862385  0.003698  \
# 1  0.002081  0.706584  0.567481    0.858017        0.661386  0.004246
# 2  0.003483  0.773137  0.664195    0.817471        0.812500  0.007189
# 3  0.001601  0.770290  0.551960    0.890663        0.619718  0.004616
# 4  0.002365  0.625060  0.235288    0.646699        0.363830  0.003864
# 5  0.003520  0.775000  0.720082    0.845950        0.851211  0.008222
# 6  0.004176  0.663985  0.517213    0.725138        0.713262  0.004669
# 7  0.002230  0.668816  0.579521    0.757344        0.765203  0.004237
# 8  0.003214  0.761602  0.569306    0.829561        0.686275  0.004226
# 9  0.002225  0.543655  0.022956    0.547117        0.041958  0.004162
#
#    val_accuracy  murmur_val_tpr  extrastole_val_tpr  time_this_iter_s  ...
# 0      0.695122        0.333333            0.294118          7.426954  ...  \
# 1      0.421642        0.529412            0.416667          7.442525  ...
# 2      0.616279        0.716981            0.352941          7.444022  ...
# 3      0.337121        0.676471            0.256410          7.182968  ...
# 4      0.751037        0.388889            0.281250          7.392783  ...
# 5      0.591603        0.696429            0.000000          7.728003  ...
# 6      0.474359        0.414286            0.454545          7.355188  ...
# 7      0.593361        0.468085            0.500000          7.556767  ...
# 8      0.553648        0.690909            0.096774          7.158191  ...
# 9      0.631179        0.638889            0.027027          6.976046  ...
#
#    time_since_restore  timesteps_since_restore  iterations_since_restore
# 0           82.004915                        0                        10  \
# 1           78.328189                        0                        10
# 2           78.093661                        0                        10
# 3           75.942375                        0                        10
# 4           77.402075                        0                        10
# 5           79.037829                        0                        10
# 6           77.616790                        0                        10
# 7           80.163190                        0                        10
# 8           75.316018                        0                        10
# 9           73.640375                        0                        10
#
#    warmup_time  config/batch_size config/dropout config/f_start
# 0     0.003143                256            0.1            100  \
# 1     0.003143                512            0.1            100
# 2     0.003143                256            0.1            300
# 3     0.003143                512            0.2            300
# 4     0.003143                512            0.2             50
# 5     0.003143                256            0.2            200
# 6     0.003143                256            0.2            300
# 7     0.003143                512            0.1              0
# 8     0.003143                256            0.1            200
# 9     0.003143                512            0.1            150
#
#   config/input_channels  config/learning_rate
# 0                   128              0.000835  \
# 1                    32              0.005662
# 2                   128              0.003920
# 3                   128              0.007495
# 4                    32              0.000477
# 5                    64              0.001785
# 6                    64              0.000420
# 7                   128              0.000470
# 8                   128              0.004523
# 9                    64              0.000146
#
#                                               logdir
# 0  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 1  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 2  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 3  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 4  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 5  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 6  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 7  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 8  /root/ray_results/train_cnn_stft_2023-04-22_20...
# 9  /root/ray_results/train_cnn_stft_2023-04-22_20...
#
# [10 rows x 33 columns]
