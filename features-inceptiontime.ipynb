# %%
import os
import librosa
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.optimizers import Adam
import matplotlib.pyplot as plt
import soundfile as sf

# %% [markdown]
# ## Prepare helping functions

# %%
# features extraction function
def extract_mfcc(audio, sample_rate, n_mfcc=40):
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=n_mfcc)
    #mfccs_scaled = np.mean(mfccs.T, axis=0)
    return mfccs

def extract_mel_spectrogram(audio, sample_rate, n_mels=32):
    mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
    return librosa.power_to_db(mel_spectrogram)

def extract_chroma_features(audio, sample_rate):
    chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
    return chroma_features

def extract_spectral_contrast(audio, sample_rate):
    spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
    return spectral_contrast

def extract_tonnetz(audio, sample_rate):
    tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)
    return tonnetz

def extract_zero_crossing_rate(audio):
    zero_crossing_rate = librosa.feature.zero_crossing_rate(audio)
    return zero_crossing_rate

# %%
# functions for data augmentation
def time_stretch(audio, rate):
    return librosa.effects.time_stretch(audio, rate)

def pitch_shift(audio, sample_rate, n_steps):
    return librosa.effects.pitch_shift(audio, sample_rate, n_steps)

def add_noise(audio, noise_factor):
    noise = np.random.randn(len(audio))
    return audio + noise_factor * noise

def augment_audio(audio, sample_rate):
    # Time stretching
    stretch_rate = np.random.uniform(0.8, 1.2)
    stretched_audio = time_stretch(audio, stretch_rate)

    # Pitch shifting
    n_steps = np.random.randint(-2, 3)
    shifted_audio = pitch_shift(audio, sample_rate, n_steps)

    # Adding noise
    noise_factor = np.random.uniform(0.005, 0.05)
    noisy_audio = add_noise(audio, noise_factor)

    return [stretched_audio, shifted_audio, noisy_audio]


def augment_and_save(file_path, output_dir):
    audio, sample_rate = librosa.load(file_path)
    augmented_audios = augment_audio(audio, sample_rate)

    file_name, ext = os.path.splitext(os.path.basename(file_path))
    
    for i, augmented_audio in enumerate(augmented_audios):
        output_file_path = os.path.join(output_dir, f"{file_name}_augmented_{i + 1}{ext}")
        sf.write(output_file_path, augmented_audio, sample_rate)


# # Augmenting minor classes

# data_path = 'dataset/set_b'
# output_dir = 'dataset/augmented_data'
# for file in os.listdir(data_path):
#     if file.endswith('.wav'):
#         file_path = os.path.join(data_path, file)
#         if file.startswith('murmur') and 'augmented' not in file_path:
#             augment_and_save(file_path, output_dir)
#         elif file.startswith('extrastole') and 'augmented' not in file_path:
#             augment_and_save(file_path, output_dir)
# Out:
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8390004759442441 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:5: FutureWarning: Pass sr=22050, n_steps=2 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.pitch_shift(audio, sample_rate, n_steps)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8856965557649729 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:5: FutureWarning: Pass sr=22050, n_steps=1 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.pitch_shift(audio, sample_rate, n_steps)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0016309061209954 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:5: FutureWarning: Pass sr=22050, n_steps=0 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.pitch_shift(audio, sample_rate, n_steps)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.053467024569863 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:5: FutureWarning: Pass sr=22050, n_steps=-1 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.pitch_shift(audio, sample_rate, n_steps)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0723591993397261 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8324677994371856 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8152870352092108 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8566311613806501 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:5: FutureWarning: Pass sr=22050, n_steps=-2 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.pitch_shift(audio, sample_rate, n_steps)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9048053460390592 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.020099625548845 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8563138695376403 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9237486196233272 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9726847004208693 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9353232360874095 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0552361372657162 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.156694980652921 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.060332281692415 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0787474557689054 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1341642273842538 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1301226708224688 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.192310570238889 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.927896226379977 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0336841032280675 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8425215203714718 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0652139793906057 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9795250020720847 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0155303932330615 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1781861280324188 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8360258001509776 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9711625732454808 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1135858491253 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9596324216760784 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8357457638337047 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1599951959782384 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1870772470241842 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9394286184144074 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1875473852969327 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8054520065968389 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8833816972207054 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.976832110210481 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8073827970568095 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9811994086692122 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8558819468756803 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8809200155018508 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.006423195028824 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1234635361483614 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8293761977936164 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1727525724942767 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.019723244515146 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.832298320177096 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9378664492420171 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9978954049423611 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1072718141075106 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8432495735391845 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8502654811689272 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.133423294259602 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8694923300714507 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8794042266206714 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9373179082058967 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0074123874359022 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8219432335502752 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.049797579445107 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.034766139587846 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8091773111267988 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9289148740681321 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1616367879251188 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0764148505425202 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.036121956930499 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.132104751842633 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8805877416256179 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8110098051682306 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8603998950511383 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1111191507873914 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.169331987780947 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8490452784474176 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8599147751606652 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9162338538091327 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9463085432147301 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9655231605613026 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0093443481769424 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9922373481516967 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8886808231353199 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8254009863416164 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0222527133400547 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1362212078006984 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1821542477891325 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1828884320559363 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9839128805428773 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.900240287913755 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.085198882058257 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0823925310611462 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8152861846866573 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9329955960135827 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0942951567389392 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8469879410172059 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0729391108635533 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1038673483050059 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1279393018457213 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0541789194861035 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0898652214794378 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9225209980953385 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9481168872832878 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.074026298145747 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.133734608745066 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.100719045922608 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9497813339357356 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8932288101494342 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8979974584298115 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0716576691897886 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9549788896928793 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0810659117685943 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8159640595433038 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9334439383775511 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8956451973872938 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8192877302860799 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.075859156126944 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0266556692484023 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8604383779192343 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8009731635371709 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1697888769634373 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9341598274385302 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0395387645544392 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1044087003194654 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9485384165214599 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1932350111744168 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9674413834833111 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1951636184793082 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9607791118676664 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8172609457182181 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8557245302717027 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1716490348854076 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0337567793207982 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.092159004059585 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1129684609373633 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8922147169698965 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.1267563779998242 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0171966370372 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8660158775124452 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.9555567864382519 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=1.0620795900095292 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/3051900860.py:2: FutureWarning: Pass rate=0.8713799351262497 as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   return librosa.effects.time_stretch(audio, rate)

# %%
# extract features from audio files
def extract_features(file_name, fixed_length=5):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
    target_length = int(fixed_length * sample_rate)

    if len(audio) < target_length:
        # Pad the audio signal with zeros
        audio = np.pad(audio, (0, target_length - len(audio)), mode='constant')
    elif len(audio) > target_length:
        # Truncate the audio signal
        audio = audio[:target_length]

    mfccs = extract_mfcc(audio, sample_rate) # No. of features = 40 
    mel_spectrogram = extract_mel_spectrogram(audio, sample_rate) # No. of features = 32
    chroma_features = extract_chroma_features(audio, sample_rate) # No. of features = 12
    spectral_contrast = extract_spectral_contrast(audio, sample_rate) # No. of features = 7
    tonnetz = extract_tonnetz(audio, sample_rate) # No. of features = 6 
    zero_crossing_rate = extract_zero_crossing_rate(audio) # No. of features = 1

    combined_features = np.concatenate([
        mfccs,
        mel_spectrogram,
        chroma_features,
        spectral_contrast,
        tonnetz,
        zero_crossing_rate
    ])
    
    return combined_features

# load data helping function
def load_data(data_path, augment):
    features = []
    labels = []
    
    if not augment:
        for file in os.listdir(data_path):
            if file.startswith('normal'):
                label = 'normal'
            elif file.startswith('murmur'):
                label = 'murmur'
            elif file.startswith('extrastole'):
                label = 'extrastole'
            else:
                # Ignore files that do not belong to the three classes
                continue

            file_path = os.path.join(data_path, file)
            feature = extract_features(file_path)
            features.append(feature)
            labels.append(label)

    elif augment:
        augmented_dir = 'dataset/augmented_data'
        for file in os.listdir(augmented_dir):
            if file.startswith('normal'):
                label = 'normal'
            elif file.startswith('murmur'):
                label = 'murmur'
            elif file.startswith('extrastole'):
                label = 'extrastole'
            else:
                # Ignore files that do not belong to the three classes
                continue

            file_path = os.path.join(augmented_dir, file)
            feature = extract_features(file_path)
            features.append(feature)
            labels.append(label)
    
    return np.array(features), np.array(labels)

# %%
# feature selection function
def select_feature(data, feature='all'):
    if feature == 'all':
        return data
    elif feature == 'mfccs': 
        return data[:, 0:40]
    elif feature == 'mel_spectrogram': 
        return data[:, 40:72]
    elif feature == 'chroma_features': 
        return data[:, 72:84]
    elif feature == 'spectral_contrast': 
        return data[:, 84:91]
    elif feature == 'tonnetz': 
        return data[:, 91:97]
    elif feature == 'zero_crossing_rate': 
        return data[:, 97:]

# %% [markdown]
# ## Load data

# %%
# Load data and split into train and test sets before added augmented data to train set
data_path = 'dataset/set_b'  # Replace with the path to your dataset

X, y = load_data(data_path, augment=False)

le = LabelEncoder()
y_encoded = le.fit_transform(y)

X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)
X_train_augmented, y_train_augmented = load_data(data_path, augment=True)
# Out:
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:7: FutureWarning: Pass y=[0.01378156 0.01590778 0.01755213 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:11: FutureWarning: Pass y=[0.01378156 0.01590778 0.01755213 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:15: FutureWarning: Pass y=[0.01378156 0.01590778 0.01755213 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[0.01378156 0.01590778 0.01755213 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:7: FutureWarning: Pass y=[ 0.00991672  0.011419    0.01254516 ... -0.00473021 -0.00530513
#  -0.00597504] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:11: FutureWarning: Pass y=[ 0.00991672  0.011419    0.01254516 ... -0.00473021 -0.00530513
#  -0.00597504] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:15: FutureWarning: Pass y=[ 0.00991672  0.011419    0.01254516 ... -0.00473021 -0.00530513
#  -0.00597504] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[ 0.00991672  0.011419    0.01254516 ... -0.00473021 -0.00530513
#  -0.00597504] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:7: FutureWarning: Pass y=[0.052344   0.05732198 0.06002162 ... 0.00152286 0.00272461 0.00318028] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:11: FutureWarning: Pass y=[0.052344   0.05732198 0.06002162 ... 0.00152286 0.00272461 0.00318028] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:15: FutureWarning: Pass y=[0.052344   0.05732198 0.06002162 ... 0.00152286 0.00272461 0.00318028] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[0.052344   0.05732198 0.06002162 ... 0.00152286 0.00272461 0.00318028] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:7: FutureWarning: Pass y=[0.00612289 0.00688195 0.00728041 ... 0.01097118 0.01091841 0.01021697] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:11: FutureWarning: Pass y=[0.00612289 0.00688195 0.00728041 ... 0.01097118 0.01091841 0.01021697] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:15: FutureWarning: Pass y=[0.00612289 0.00688195 0.00728041 ... 0.01097118 0.01091841 0.01021697] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[0.00612289 0.00688195 0.00728041 ... 0.01097118 0.01091841 0.01021697] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:7: FutureWarning: Pass y=[ 0.01531158  0.01689764  0.01786108 ... -0.01164331 -0.01065585
#  -0.00967666] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:11: FutureWarning: Pass y=[ 0.01531158  0.01689764  0.01786108 ... -0.01164331 -0.01065585
#  -0.00967666] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:15: FutureWarning: Pass y=[ 0.01531158  0.01689764  0.01786108 ... -0.01164331 -0.01065585
#  -0.00967666] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[ 0.01531158  0.01689764  0.01786108 ... -0.01164331 -0.01065585
#  -0.00967666] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:7: FutureWarning: Pass y=[0.02458599 0.02764309 0.02986731 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:11: FutureWarning: Pass y=[0.02458599 0.02764309 0.02986731 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:15: FutureWarning: Pass y=[0.02458599 0.02764309 0.02986731 ... 0.         0.         0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[0
...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[ 0.02035522  0.0406189  -0.00796509 ...  0.          0.
#   0.        ] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:7: FutureWarning: Pass y=[-0.05822754 -0.06954956 -0.0668335  ...  0.2626648   0.2558899
#   0.24908447] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:11: FutureWarning: Pass y=[-0.05822754 -0.06954956 -0.0668335  ...  0.2626648   0.2558899
#   0.24908447] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:15: FutureWarning: Pass y=[-0.05822754 -0.06954956 -0.0668335  ...  0.2626648   0.2558899
#   0.24908447] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[-0.05822754 -0.06954956 -0.0668335  ...  0.2626648   0.2558899
#   0.24908447] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:7: FutureWarning: Pass y=[-0.00109863 -0.00134277 -0.00158691 ...  0.17404175  0.17822266
#   0.18240356] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   mel_spectrogram = librosa.feature.melspectrogram(audio, sr=sample_rate, n_mels=n_mels)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:11: FutureWarning: Pass y=[-0.00109863 -0.00134277 -0.00158691 ...  0.17404175  0.17822266
#   0.18240356] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   chroma_features = librosa.feature.chroma_stft(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:15: FutureWarning: Pass y=[-0.00109863 -0.00134277 -0.00158691 ...  0.17404175  0.17822266
#   0.18240356] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   spectral_contrast = librosa.feature.spectral_contrast(audio, sr=sample_rate)
# /var/folders/_x/rz46g3hj1cz4fngzll68ykdm0000gn/T/ipykernel_78630/4294816581.py:19: FutureWarning: Pass y=[-0.00109863 -0.00134277 -0.00158691 ...  0.17404175  0.17822266
#   0.18240356] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   tonnetz = librosa.feature.tonnetz(audio, sr=sample_rate)

# %%
X_train_augmented.shape
# Out:
# (423, 98, 216)

# %%
X_train_extra = np.append(X_train, X_train_augmented, axis=0)
y_train_extra = np.append(y_train, le.fit_transform(y_train_augmented))
y_categorical_train = to_categorical(y_train_extra)
y_categorical_test = to_categorical(y_test)

# %%
print(X_train_extra.shape)
print(y_train_extra.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (791, 98, 216)
# (791,)
# (93, 98, 216)
# (93,)

# %% [markdown]
# ## Construct InceptionTime model using tensorflow

# %%
from keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Concatenate, Input
from keras.models import Model

def inception_module(input_tensor, n_filters=32):
    # 1x1 convolution
    conv1 = Conv1D(n_filters, 1, activation='relu', padding='same')(input_tensor)

    # 3x3 convolution followed by 1x1 convolution
    conv3 = Conv1D(n_filters, 3, activation='relu', padding='same')(input_tensor)
    conv3 = Conv1D(n_filters, 1, activation='relu', padding='same')(conv3)

    # 5x5 convolution followed by 1x1 convolution
    conv5 = Conv1D(n_filters, 5, activation='relu', padding='same')(input_tensor)
    conv5 = Conv1D(n_filters, 1, activation='relu', padding='same')(conv5)

    # 3x3 max pooling followed by 1x1 convolution
    pool = MaxPooling1D(3, strides=1, padding='same')(input_tensor)
    pool = Conv1D(n_filters, 1, activation='relu', padding='same')(pool)

    # Concatenate the outputs of the four branches
    output = Concatenate(axis=-1)([conv1, conv3, conv5, pool])
    return output

def create_inceptiontime_model(input_shape, num_classes, n_filters=32, n_modules=6):
    input_tensor = Input(shape=input_shape)

    x = input_tensor
    for _ in range(n_modules):
        x = inception_module(x, n_filters)

    x = GlobalAveragePooling1D()(x)
    x = Dense(num_classes, activation='softmax')(x)

    model = Model(input_tensor, x)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

input_shape = (X_train_extra.shape[1], X_train_extra.shape[2])
num_classes = len(np.unique(y_encoded))

inceptiontime_model = create_inceptiontime_model(input_shape, num_classes)
inceptiontime_model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 98, 216)]    0           []
#
#  conv1d_73 (Conv1D)             (None, 98, 32)       20768       ['input_3[0][0]']
#
#  conv1d_75 (Conv1D)             (None, 98, 32)       34592       ['input_3[0][0]']
#
#  max_pooling1d_12 (MaxPooling1D  (None, 98, 216)     0           ['input_3[0][0]']
#  )
#
#  conv1d_72 (Conv1D)             (None, 98, 32)       6944        ['input_3[0][0]']
#
#  conv1d_74 (Conv1D)             (None, 98, 32)       1056        ['conv1d_73[0][0]']
#
#  conv1d_76 (Conv1D)             (None, 98, 32)       1056        ['conv1d_75[0][0]']
#
#  conv1d_77 (Conv1D)             (None, 98, 32)       6944        ['max_pooling1d_12[0][0]']
#
#  concatenate_12 (Concatenate)   (None, 98, 128)      0           ['conv1d_72[0][0]',
#                                                                   'conv1d_74[0][0]',
#                                                                   'conv1d_76[0][0]',
#                                                                   'conv1d_77[0][0]']
#
#  conv1d_79 (Conv1D)             (None, 98, 32)       12320       ['concatenate_12[0][0]']
#
#  conv1d_81 (Conv1D)             (None, 98, 32)       20512       ['concatenate_12[0][0]']
#
#  max_pooling1d_13 (MaxPooling1D  (None, 98, 128)     0           ['concatenate_12[0][0]']
#  )
#
#  conv1d_78 (Conv1D)             (None, 98, 32)       4128        ['concatenate_12[0][0]']
#
#  conv1d_80 (Conv1D)             (None, 98, 32)       1056        ['conv1d_79[0][0]']
#
#  conv1d_82 (Conv1D)             (None, 98, 32)       1056        ['conv1d_81[0][0]']
#
#  conv1d_83 (Conv1D)             (None, 98, 32)       4128        ['max_pooling1d_13[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 98, 128)      0           ['conv1d_78[0][0]',
#                                                                   'conv1d_80[0][0]',
#                                                                   'conv1d_82[0][0]',
#                                                                   'conv1d_83[0][0]']
#
#  conv1d_85 (Conv1D)             (None, 98, 32)       12320       ['concatenate_13[0][0]']
#
#  conv1d_87 (Conv1D)             (None, 98, 32)       20512       ['concatenate_13[0][0]']
#
#  max_pooling1d_14 (MaxPooling1D  (None, 98, 128)     0           ['concatenate_13[0][0]']
#  )
#
#  conv1d_84 (Conv1D)             (None, 98, 32)       4128        ['concatenate_13[0][0]']
#
#  conv1d_86 (Conv1D)             (None, 98, 32)       1056        ['conv1d_85[0][0]']
#
#  conv1d_88 (Conv1D)             (None, 98, 32)       1056        ['conv1d_87[0][0]']
#
#  conv1d_89 (Conv1D)             (None, 98, 32)       4128        ['max_pooling1d_14[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 98, 128)      0           ['conv1d_84[0][0]',
#                                                                   'conv1d_86[0][0]',
#                                                                   'conv1d_88[0][0]',
#                                                                   'conv1d_89[0][0]']
#
#  conv1d_91 (Conv1D)             (None, 98, 32)       12320       ['concatenate_14[0][0]']
#
#  conv1d_93 (Conv1D)             (None, 98, 32)       20512       ['concatenate_14[0][0]']
#
#  max_pooling1d_15 (MaxPooling1D  (None, 98, 128)     0           ['concatenate_14[0][0]']
#  )
#
#  conv1d_90 (Conv1D)             (None, 98, 32)       4128        ['concatenate_14[0][0]']
#
#  conv1d_92 (Conv1D)             (None, 98, 32)       1056        ['conv1d_91[0][0]']
#
#  conv1d_94 (Conv1D)             (None, 98, 32)       1056        ['conv1d_93[0][0]']
#
#  conv1d_95 (Conv1D)             (None, 98, 32)       4128        ['max_pooling1d_15[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 98, 128)      0           ['conv1d_90[0][0]',
#                                                                   'conv1d_92[0][0]',
#                                                                   'conv1d_94[0][0]',
#                                                                   'conv1d_95[0][0]']
#
#  conv1d_97 (Conv1D)             (None, 98, 32)       12320       ['concatenate_15[0][0]']
#
#  conv1d_99 (Conv1D)             (None, 98, 32)       20512       ['concatenate_15[0][0]']
#
#  max_pooling1d_16 (MaxPooling1D  (None, 98, 128)     0           ['concatenate_15[0][0]']
#  )
#
#  conv1d_96 (Conv1D)             (None, 98, 32)       4128        ['concatenate_15[0][0]']
#
#  conv1d_98 (Conv1D)             (None, 98, 32)       1056        ['conv1d_97[0][0]']
#
#  conv1d_100 (Conv1D)            (None, 98, 32)       1056        ['conv1d_99[0][0]']
#
#  conv1d_101 (Conv1D)            (None, 98, 32)       4128        ['max_pooling1d_16[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 98, 128)      0           ['conv1d_96[0][0]',
#                                                                   'conv1d_98[0][0]',
#                                                                   'conv1d_100[0][0]',
#                                                                   'conv1d_101[0][0]']
#
#  conv1d_103 (Conv1D)            (None, 98, 32)       12320       ['concatenate_16[0][0]']
#
#  conv1d_105 (Conv1D)            (None, 98, 32)       20512       ['concatenate_16[0][0]']
#
#  max_pooling1d_17 (MaxPooling1D  (None, 98, 128)     0           ['concatenate_16[0][0]']
#  )
#
#  conv1d_102 (Conv1D)            (None, 98, 32)       4128        ['concatenate_16[0][0]']
#
#  conv1d_104 (Conv1D)            (None, 98, 32)       1056        ['conv1d_103[0][0]']
#
#  conv1d_106 (Conv1D)            (None, 98, 32)       1056        ['conv1d_105[0][0]']
#
#  conv1d_107 (Conv1D)            (None, 98, 32)       4128        ['max_pooling1d_17[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 98, 128)      0           ['conv1d_102[0][0]',
#                                                                   'conv1d_104[0][0]',
#                                                                   'conv1d_106[0][0]',
#                                                                   'conv1d_107[0][0]']
#
#  global_average_pooling1d_2 (Gl  (None, 128)         0           ['concatenate_17[0][0]']
#  obalAveragePooling1D)
#
#  dense_2 (Dense)                (None, 3)            387         ['global_average_pooling1d_2[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 287,747
# Trainable params: 287,747
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Run and Collect results

# %%
from sklearn.utils import class_weight
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

class_weights = class_weight.compute_class_weight(class_weight = 'balanced', classes = np.unique(y_train_extra), y = y_train_extra)
class_weight_dict = dict(enumerate(class_weights))
epochs = 50
batch_size = 32
#callback = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)


for feature in ['mfccs','mel_spectrogram','chroma_features',
            'spectral_contrast','tonnetz','zero_crossing_rate', 'all']:
    
    X_train_feature = select_feature(X_train_extra, feature)
    X_test_feature = select_feature(X_test, feature)

    input_shape = (X_train_feature.shape[1], X_train_feature.shape[2])
    num_classes = len(np.unique(y_train_extra))
    inceptiontime_model = create_inceptiontime_model(input_shape, num_classes)
    model_history = inceptiontime_model.fit(X_train_feature, y_categorical_train, batch_size=batch_size, epochs=epochs, 
                                            validation_split=0.1, class_weight=class_weight_dict, verbose = 0)
    # model_test_loss, model_test_accuracy = inceptiontime_model.evaluate(X_test, y_categorical_test)
    # print("Accuracy: ", model_test_accuracy)

    y_pred = [np.argmax(y, axis=None, out=None) for y in inceptiontime_model.predict(X_test_feature, verbose = 0)]
    target_names = ['extrasystole', 'murmur', 'normal']
    print(feature)
    print(confusion_matrix(y_test, y_pred))
    print(classification_report(y_test, y_pred, target_names=target_names))
    print("--------------------------------------------------------------")
# Out:
# mfccs
# [[ 5  1  5]
#  [ 1 14  4]
#  [ 5 13 45]]
#               precision    recall  f1-score   support
#
# extrasystole       0.45      0.45      0.45        11
#       murmur       0.50      0.74      0.60        19
#       normal       0.83      0.71      0.77        63
#
#     accuracy                           0.69        93
#    macro avg       0.60      0.64      0.61        93
# weighted avg       0.72      0.69      0.70        93
#
# --------------------------------------------------------------
# mel_spectrogram
# [[10  1  0]
#  [ 0 19  0]
#  [ 4 12 47]]
#               precision    recall  f1-score   support
#
# extrasystole       0.71      0.91      0.80        11
#       murmur       0.59      1.00      0.75        19
#       normal       1.00      0.75      0.85        63
#
#     accuracy                           0.82        93
#    macro avg       0.77      0.89      0.80        93
# weighted avg       0.88      0.82      0.83        93
#
# --------------------------------------------------------------
# chroma_features
# [[ 3  0  8]
#  [ 0 12  7]
#  [ 1 18 44]]
#               precision    recall  f1-score   support
#
# extrasystole       0.75      0.27      0.40        11
#       murmur       0.40      0.63      0.49        19
#       normal       0.75      0.70      0.72        63
#
#     accuracy                           0.63        93
#    macro avg       0.63      0.53      0.54        93
# weighted avg       0.68      0.63      0.64        93
#
# --------------------------------------------------------------
# WARNING:tensorflow:5 out of the last 16 calls to <function Model.make_predict_function.<locals>.predict_function at 0x39573ec10> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# spectral_contrast
# [[ 2  0  9]
#  [ 2  5 12]
#  [ 6 13 44]]
#               precision    recall  f1-score   support
#
# extrasystole       0.20      0.18      0.19        11
#       murmur       0.28      0.26      0.27        19
#       normal       0.68      0.70      0.69        63
#
#     accuracy                           0.55        93
#    macro avg       0.38      0.38      0.38        93
# weighted avg       0.54      0.55      0.54        93
#
# --------------------------------------------------------------
# tonnetz
# [[ 9  1  1]
#  [ 0 16  3]
#  [ 5 41 17]]
#               precision    recall  f1-score   support
#
# extrasystole       0.64      0.82      0.72        11
#       murmur       0.28      0.84      0.42        19
#       normal       0.81      0.27      0.40        63
#
#     accuracy                           0.45        93
#    macro avg       0.58      0.64      0.51        93
# weighted avg       0.68      0.45      0.44        93
#
# --------------------------------------------------------------
# zero_crossing_rate
# [[ 8  1  2]
#  [ 3 12  4]
#  [17 16 30]]
#               precision    recall  f1-score   support
#
# extrasystole       0.29      0.73      0.41        11
#       murmur       0.41      0.63      0.50        19
#       normal       0.83      0.48      0.61        63
#
#     accuracy                           0.54        93
#    macro avg       0.51      0.61      0.51        93
# weighted avg       0.68      0.54      0.56        93
#
# --------------------------------------------------------------
# all
# [[ 1  0 10]
#  [ 0  8 11]
#  [ 2  8 53]]
#               precision    recall  f1-score   support
#
# extrasystole       0.33      0.09      0.14        11
#       murmur       0.50      0.42      0.46        19
#       normal       0.72      0.84      0.77        63
#
#     accuracy                           0.67        93
#    macro avg       0.52      0.45      0.46        93
# weighted avg       0.63      0.67      0.63        93
#
# --------------------------------------------------------------
